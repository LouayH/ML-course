# %%
import pandas as pd

# %%
dataframe = pd.read_csv("datasets/students-scores.csv")

dataframe.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
dataframe["math score"].plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
dataframe.plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
dataframe.plot(kind="density", subplots=True, layout=(2, 2), sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
dataframe.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
dataframe["writing score"].plot(kind="box")
# Out:
# <Axes: >

# %%
dataframe.plot(kind="box")
# Out:
# <Axes: >

# %%
dataframe.plot(kind="box", subplots=True, layout=(2, 2), sharex=False)
# Out:
# math score          Axes(0.125,0.53;0.352273x0.35)
# reading score    Axes(0.547727,0.53;0.352273x0.35)
# writing score       Axes(0.125,0.11;0.352273x0.35)
# dtype: object
