# %%
import pandas as pd

dataframe = pd.read_json("datasets/movies.json")
dataframe
# Out:
#                                          title  year  \
# 0                   After Dark in Central Park  1900
# 1         Boarding School Girls' Pajama Parade  1900
# 2               Buffalo Bill's Wild West Parad  1900
# 3                                       Caught  1900
# 4                         Clowns Spinning Hats  1900
# ...                                        ...   ...
# 36268             Aquaman and the Lost Kingdom  2023
# 36269  Untitled Ghostbusters: Afterlife sequel  2023
# 36270                               Rebel Moon  2023
# 36271                                Migration  2023
# 36272                         The Color Purple  2023
#
#                                                     cast  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# ...

# %%
dataframe.head()
# Out:
#                                   title  year cast    genres  \
# 0            After Dark in Central Park  1900   []        []
# 1  Boarding School Girls' Pajama Parade  1900   []        []
# 2        Buffalo Bill's Wild West Parad  1900   []        []
# 3                                Caught  1900   []        []
# 4                  Clowns Spinning Hats  1900   []  [Silent]
#
#                    href                                            extract  \
# 0                  None                                                NaN
# 1                  None                                                NaN
# 2                  None                                                NaN
# 3                  None                                                NaN
# 4  Clowns_Spinning_Hats  Clowns Spinning Hats is a black-and-white sile...
#
#   thumbnail  thumbnail_width  thumbnail_height
# 0       NaN              NaN               NaN
# 1       NaN              NaN               NaN
# ...

# %%
dataframe.sample(5)
# Out:
#                                         title  year  \
# 30184  The Adventures of Rocky and Bullwinkle  2000
# 22050                   The Clown and the Kid  1961
# 28472                             Love Affair  1994
# 13057                     Fight for Your Lady  1937
# 25844                             Harry & Son  1984
#
#                                                     cast  \
# 30184  [Rene Russo, Jason Alexander, Robert De Niro, ...
# 22050     [John Lupton, Michael McGreevey, Mary Webster]
# 28472  [Warren Beatty, Annette Bening, Garry Shandlin...
# 13057               [John Boles, Ida Lupino, Jack Oakie]
# 25844  [Paul Newman, Robby Benson, Ellen Barkin, Judi...
#
#                                            genres  \
# 30184  [Comedy, Live Action, Adventure, Animated]
# 22050                                     [Drama]
# 28472                    [Romance, Comedy, Drama]
# 13057                           [Romance, Comedy]
# ...

# %%
dataframe.tail()
# Out:
#                                          title  year  \
# 36268             Aquaman and the Lost Kingdom  2023
# 36269  Untitled Ghostbusters: Afterlife sequel  2023
# 36270                               Rebel Moon  2023
# 36271                                Migration  2023
# 36272                         The Color Purple  2023
#
#                                                     cast  \
# 36268  [Jason Momoa, Amber Heard, Willem Dafoe, Patri...
# 36269  [Mckenna Grace, Carrie Coon, Finn Wolfhard, Pa...
# 36270  [Sofia Boutella, Charlie Hunnam, Ray Fisher, D...
# 36271                                                 []
# 36272  [Fantasia Barrino, Colman Domingo, Corey Hawki...
#
#                              genres                                     href  \
# 36268                   [Superhero]             Aquaman_and_the_Lost_Kingdom
# 36269        [Comedy, Supernatural]  Untitled_Ghostbusters:_Afterlife_sequel
# ...
